# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as pt
import seaborn as sns
# %matplotlib inline

# %%
#Load Dataset
athletes = pd.read_csv('athlete_events.csv')

# %%
athletes
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
#Print the five first rows
athletes.head()
# Out:
#    ID                      Name Sex   Age  Height  Weight            Team  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0           China
# 1   2                  A Lamusi   M  23.0   170.0    60.0           China
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
#
#    NOC        Games  Year  Season       City          Sport  \
# 0  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  CHN  2012 Summer  2012  Summer     London           Judo
# 2  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# ...

# %%
#Print the five last rows
athletes.tail()
# Out:
#             ID                Name Sex   Age  Height  Weight      Team  NOC  \
# 271111  135569          Andrzej ya   M  29.0   179.0    89.0  Poland-1  POL
# 271112  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271113  135570            Piotr ya   M  27.0   176.0    59.0    Poland  POL
# 271114  135571  Tomasz Ireneusz ya   M  30.0   185.0    96.0    Poland  POL
# 271115  135571  Tomasz Ireneusz ya   M  34.0   185.0    96.0    Poland  POL
#
#               Games  Year  Season            City        Sport  \
# 271111  1976 Winter  1976  Winter       Innsbruck         Luge
# 271112  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271113  2014 Winter  2014  Winter           Sochi  Ski Jumping
# 271114  1998 Winter  1998  Winter          Nagano    Bobsleigh
# 271115  2002 Winter  2002  Winter  Salt Lake City    Bobsleigh
#
#                                            Event Medal
# 271111                Luge Mixed (Men)'s Doubles   NaN
# ...

# %%
athletes.shape
# Out:
# (271116, 15)

# %%
athletes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 15 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   ID      271116 non-null  int64
#  1   Name    271116 non-null  object
#  2   Sex     271116 non-null  object
#  3   Age     261642 non-null  float64
#  4   Height  210945 non-null  float64
#  5   Weight  208241 non-null  float64
#  6   Team    271116 non-null  object
#  7   NOC     271116 non-null  object
#  8   Games   271116 non-null  object
#  9   Year    271116 non-null  int64
#  10  Season  271116 non-null  object
#  11  City    271116 non-null  object
#  12  Sport   271116 non-null  object
#  13  Event   271116 non-null  object
#  14  Medal   39783 non-null   object
# dtypes: float64(3), int64(2), object(10)
# memory usage: 31.0+ MB

# %%
athletes.describe()
# Out:
#                   ID            Age         Height         Weight  \
# count  271116.000000  261642.000000  210945.000000  208241.000000
# mean    68248.954396      25.556898     175.338970      70.702393
# std     39022.286345       6.393561      10.518462      14.348020
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34643.000000      21.000000     168.000000      60.000000
# 50%     68205.000000      24.000000     175.000000      70.000000
# 75%    102097.250000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                 Year
# count  271116.000000
# mean     1978.378480
# std        29.877632
# min      1896.000000
# 25%      1960.000000
# 50%      1988.000000
# 75%      2002.000000
# max      2016.000000

# %%
#Check null values
null_values = athletes.isna()
null_columns = null_values.any()
null_columns
# Out:
# ID        False
# Name      False
# Sex       False
# Age        True
# Height     True
# Weight     True
# Team      False
# NOC       False
# Games     False
# Year      False
# Season    False
# City      False
# Sport     False
# Event     False
# Medal      True
# dtype: bool

# %%
#Print the columns names containing null values or missing values in the form of a list
print(athletes[athletes.Age.isnull()])
print(athletes[athletes.Height.isnull()])
print(athletes[athletes.Weight.isnull()])
print(athletes[athletes.Medal.isnull()])
# Out:
#             ID                   Name Sex  Age  Height  Weight         Team  \
# 147         54  Mohamed Jamshid Abadi   M  NaN     NaN     NaN         Iran
# 152         58       Georgi Abadzhiev   M  NaN     NaN     NaN     Bulgaria
# 153         58       Georgi Abadzhiev   M  NaN     NaN     NaN     Bulgaria
# 162         66        Mohamed Abakkar   M  NaN   156.0    48.0        Sudan
# 212        102      Sayed Fahmy Abaza   M  NaN     NaN     NaN        Egypt
# ...        ...                    ...  ..  ...     ...     ...          ...
# 270679  135368      Antonio A. Zucchi   M  NaN     NaN     NaN    Argentina
# 270774  135416              Star Zulu   M  NaN     NaN     NaN       Zambia
# 270793  135426           Max Zumstein   M  NaN     NaN     NaN  Switzerland
# 270804  135434     Edmundo Ziga Erraz   M  NaN   180.0    95.0        Chile
# 270805  135435             Faelo Ziga   M  NaN     NaN     NaN        Chile
#
# ...

# %%
#Filtering india details
athletes[athletes['Team']=='India'].head()
# Out:
#       ID                             Name Sex   Age  Height  Weight   Team  \
# 505  281                   S. Abdul Hamid   M   NaN     NaN     NaN  India
# 506  281                   S. Abdul Hamid   M   NaN     NaN     NaN  India
# 895  512  Shiny Kurisingal Abraham-Wilson   F  19.0   167.0    53.0  India
# 896  512  Shiny Kurisingal Abraham-Wilson   F  19.0   167.0    53.0  India
# 897  512  Shiny Kurisingal Abraham-Wilson   F  23.0   167.0    53.0  India
#
#      NOC        Games  Year  Season         City      Sport  \
# 505  IND  1928 Summer  1928  Summer    Amsterdam  Athletics
# 506  IND  1928 Summer  1928  Summer    Amsterdam  Athletics
# 895  IND  1984 Summer  1984  Summer  Los Angeles  Athletics
# 896  IND  1984 Summer  1984  Summer  Los Angeles  Athletics
# 897  IND  1988 Summer  1988  Summer        Seoul  Athletics
#
#                                       Event Medal
# 505      Athletics Men's 110 metres Hurdles   NaN
# 506      Athletics Men's 400 metres Hurdles   NaN
# ...

# %%
#Filtering japan details
athletes[athletes['Team']=='Japan'].head()
# Out:
#       ID         Name Sex   Age  Height  Weight   Team  NOC        Games  \
# 625  362  Isao Ko Abe   M  24.0   177.0    75.0  Japan  JPN  1936 Summer
# 629  363   Kazumi Abe   M  28.0   178.0    67.0  Japan  JPN  1976 Winter
# 630  364    Kazuo Abe   M  25.0   166.0    69.0  Japan  JPN  1960 Summer
# 631  365    Kinya Abe   M  23.0   168.0    68.0  Japan  JPN  1992 Summer
# 632  366  Kiyoshi Abe   M  25.0   167.0    62.0  Japan  JPN  1972 Summer
#
#      Year  Season       City      Sport  \
# 625  1936  Summer     Berlin  Athletics
# 629  1976  Winter  Innsbruck  Bobsleigh
# 630  1960  Summer       Roma  Wrestling
# 631  1992  Summer  Barcelona    Fencing
# 632  1972  Summer     Munich  Wrestling
#
#                                         Event Medal
# 625              Athletics Men's Hammer Throw   NaN
# 629                      Bobsleigh Men's Four   NaN
# 630    Wrestling Men's Lightweight, Freestyle   NaN
# 631            Fencing Men's Foil, Individual   NaN
# ...

# %%
#Top countries participating
countries = athletes['Team'].value_counts().sort_values(ascending=False).head(10)

# %%
countries
# Out:
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
# Canada            9279
# Japan             8289
# Sweden            8052
# Australia         7513
# Hungary           6547
# Name: Team, dtype: int64

# %%
#Plot for the top 10 countries
pt.figure(figsize=(12,6))
pt.title('Overall Participation by Country')
sns.barplot(x = countries.index, y=countries)
# Out:
# <Axes: title={'center': 'Overall Participation by Country'}, ylabel='Team'>

# %%
#Using Matplotlib
pt.figure(figsize=(12,5))
ax =athletes['Team'].value_counts().sort_values(ascending=False).head(10).plot(kind='bar')
ax.set_xlabel('Countries')
ax.set_ylabel('Team')
ax.set_title('Overall participation of countries')
# Out:
# Text(0.5, 1.0, 'Overall participation of countries')

# %%
#Age Distribution of the Participants
pt.figure(figsize=(10,5))
pt.title('Age distribution of the athletes')
pt.xlabel('Age')
pt.ylabel('Number of participant')
pt.hist(athletes.Age, bins=np.arange(10,80,2), color='orange', edgecolor='white')
pt.show()

# %%
#Winter Olympic Game
winter = athletes[athletes['Season']=='Winter'].Sport.unique()

# %%
winter
# Out:
# array(['Speed Skating', 'Cross Country Skiing', 'Ice Hockey', 'Biathlon',
#        'Alpine Skiing', 'Luge', 'Bobsleigh', 'Figure Skating',
#        'Nordic Combined', 'Freestyle Skiing', 'Ski Jumping', 'Curling',
#        'Snowboarding', 'Short Track Speed Skating', 'Skeleton',
#        'Military Ski Patrol', 'Alpinism'], dtype=object)

# %%
#Summer Olympic Game
summer = athletes[athletes['Season']=='Summer'].Sport.unique()

# %%
summer
# Out:
# array(['Basketball', 'Judo', 'Football', 'Tug-Of-War', 'Athletics',
#        'Swimming', 'Badminton', 'Sailing', 'Gymnastics',
#        'Art Competitions', 'Handball', 'Weightlifting', 'Wrestling',
#        'Water Polo', 'Hockey', 'Rowing', 'Fencing', 'Equestrianism',
#        'Shooting', 'Boxing', 'Taekwondo', 'Cycling', 'Diving', 'Canoeing',
#        'Tennis', 'Modern Pentathlon', 'Golf', 'Softball', 'Archery',
#        'Volleyball', 'Synchronized Swimming', 'Table Tennis', 'Baseball',
#        'Rhythmic Gymnastics', 'Rugby Sevens', 'Trampolining',
#        'Beach Volleyball', 'Triathlon', 'Rugby', 'Lacrosse', 'Polo',
#        'Cricket', 'Ice Hockey', 'Racquets', 'Motorboating', 'Croquet',
#        'Figure Skating', 'Jeu De Paume', 'Roque', 'Basque Pelota',
#        'Alpinism', 'Aeronautics'], dtype=object)

# %%
#Male and Female Participants
gender = athletes['Sex'].value_counts()

# %%
gender
# Out:
# M    196594
# F     74522
# Name: Sex, dtype: int64

# %%
#Plot pie for male and female
pt.title('Gender Distribution')
pt.pie(athletes['Sex'].value_counts(), labels=athletes['Sex'].unique(), autopct='%1.1f%%')
pt.show()

# %%
#Total Medals
athletes['Medal'].value_counts()
# Out:
# Gold      13372
# Bronze    13295
# Silver    13116
# Name: Medal, dtype: int64

# %%
#Total number of female athletes in each olympic
female = athletes[(athletes['Sex']=='F') & (athletes['Season']=='Summer')][['Sex','Year']]
female = female.groupby('Year').count().reset_index()

# %%
female.tail()
# Out:
#     Year   Sex
# 23  2000  5431
# 24  2004  5546
# 25  2008  5816
# 26  2012  5815
# 27  2016  6223

# %%
#Filtering female athletes in each olympic
woman = athletes[(athletes['Sex']=='F') & (athletes['Season']=='Summer')]

# %%
pt.figure(figsize=(18,9))
sns.countplot(data = woman, x='Year')
pt.title('Woman participation')
# Out:
# Text(0.5, 1.0, 'Woman participation')

# %%
#line graph
plot = woman.groupby('Year')['Sex'].value_counts()
pt.figure(figsize=(15,7))
plot.loc[:,'F'].plot()
pt.title('Plot of Female Athletes over time')
# Out:
# Text(0.5, 1.0, 'Plot of Female Athletes over time')

# %%
#Gold medal athletes
Gold = athletes[athletes['Medal'] =='Gold']

# %%
Gold.head()
# Out:
#     ID                     Name Sex   Age  Height  Weight            Team  \
# 3    4     Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 42  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 44  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 48  17  Paavo Johannes Aaltonen   M  28.0   175.0    64.0         Finland
# 60  20       Kjetil Andr Aamodt   M  20.0   176.0    85.0          Norway
#
#     NOC        Games  Year  Season         City          Sport  \
# 3   DEN  1900 Summer  1900  Summer        Paris     Tug-Of-War
# 42  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 44  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 48  FIN  1948 Summer  1948  Summer       London     Gymnastics
# 60  NOR  1992 Winter  1992  Winter  Albertville  Alpine Skiing
#
#                                Event Medal
# 3        Tug-Of-War Men's Tug-Of-War  Gold
# 42  Gymnastics Men's Team All-Around  Gold
# ...

# %%
#Take only the values that are different from NaN. 
Gold = Gold[np.isfinite(Gold['Age'])]

# %%
#Gold beyond 60
Gold['ID'][Gold['Age']>60].count()
# Out:
# 6

# %%
#Checking sport where the 6 Gold medal has come
sporting = Gold['Sport'][Gold['Age']>60]

# %%
sporting
# Out:
# 104003    Art Competitions
# 105199               Roque
# 190952             Archery
# 226374             Archery
# 233390            Shooting
# 261102             Archery
# Name: Sport, dtype: object

# %%
#Gold medals for each City
Gold['City'].value_counts().reset_index(name='Medal').head(5)
# Out:
#             index  Medal
# 0          London   1199
# 1          Athina    842
# 2     Los Angeles    721
# 3         Beijing    671
# 4  Rio de Janeiro    665

# %%
TotalGoldMedals = Gold['City'].value_counts().reset_index(name='Medal').head(6)
ax = sns.catplot(x="index", y='Medal', data=TotalGoldMedals, kind='bar', height=5,)
ax.despine(left=True)
ax.set_xlabels('Top 5 city')
ax.set_ylabels('Number of Medals')
pt.title('Gold Medal per city')
# Out:
# Text(0.5, 1.0, 'Gold Medal per city')

# %%
#rio olympics
max_year = athletes.Year.max()
print(max_year)

team_names = athletes[(athletes['Year']==max_year) & (athletes['Medal']=='Gold')].Team
team_names.value_counts().head(10)
# Out:
# 2016
# United States    137
# Great Britain     64
# Russia            50
# Germany           47
# China             44
# Brazil            34
# Australia         23
# Argentina         21
# France            20
# Japan             17
# Name: Team, dtype: int64

# %%
sns.barplot(x=team_names.value_counts().head(20), y=team_names.value_counts().head(20).index)
pt.xlabel(None)
pt.ylabel('Countrywise Medals for the year 2016')
# Out:
# Text(0, 0.5, 'Countrywise Medals for the year 2016')

# %%
not_null_medals = athletes[(athletes['Height'].notnull()) & (athletes['Weight'].notnull())]

# %%
pt.figure(figsize=(20,10))
sns.scatterplot(data = not_null_medals, x='Height', y='Weight', hue='Sex')
pt.title('Height vs Weight of olympic Medalists')
# Out:
# Text(0.5, 1.0, 'Height vs Weight of olympic Medalists')
